# %% [markdown]
# # 匯入ＣＳＶ

# %%
import pandas as pd

df = pd.read_csv('/Users/ziyon/Documents/Business Programming/Final Project/World Happiness Report 2022 - World Happiness Report 2022.csv')

df
# Out:
#      RANK      Country Continent  Happiness score  Whisker-high  Whisker-low  \
# 0       1      Finland        eu            7.821         7.886        7.756
# 1       2      Denmark        eu            7.636         7.710        7.563
# 2       3      Iceland        eu            7.557         7.651        7.464
# 3       4  Switzerland        eu            7.512         7.586        7.437
# 4       5  Netherlands        eu            7.415         7.471        7.359
# ..    ...          ...       ...              ...           ...          ...
# 141   142    Botswana*        af            3.471         3.667        3.275
# 142   143      Rwanda*        af            3.268         3.462        3.074
# 143   144     Zimbabwe        af            2.995         3.110        2.880
# 144   145      Lebanon        as            2.955         3.049        2.862
# 145   146  Afghanistan        as            2.404         2.469        2.339
#
#      Dystopia (1.83) + residual  GDP per capita  Social support  \
# 0                         2.518           1.892           1.258
# 1                         2.226           1.953           1.243
# 2                         2.320           1.936           1.320
# 3                         2.153           2.026           1.226
# 4                         2.137           1.945           1.206
# ..                          ...             ...             ...
# 141                       0.187           1.503           0.815
# 142                       0.536           0.785           0.133
# 143                       0.548           0.947           0.690
# 144                       0.216           1.392           0.498
# 145                       1.263           0.758           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                      0.775                         0.736       0.109
# 1                      0.777                         0.719       0.188
# 2                      0.803                         0.718       0.270
# 3                      0.822                         0.677       0.147
# 4                      0.787                         0.651       0.271
# ..                       ...                           ...         ...
# 141                    0.280                         0.571       0.012
# 142                    0.462                         0.621       0.187
# 143                    0.270                         0.329       0.106
# 144                    0.631                         0.103       0.082
# 145                    0.289                         0.000       0.089
#
#      Perceptions of corruption
# 0                        0.534
# 1                        0.532
# 2                        0.191
# 3                        0.461
# 4                        0.419
# ..                         ...
# 141                      0.102
# 142                      0.544
# 143                      0.105
# 144                      0.034
# 145                      0.005
#
# [146 rows x 13 columns]

# %% [markdown]
# # Set Up

# %%
#set up
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# # 各州國家數

# %%
#先做一個表來計算各州國家數
count_by_continent = df.groupby('Continent').size().reset_index(name='Count')
count_by_continent
# Out:
#   Continent  Count
# 0        af     41
# 1        as     43
# 2        eu     40
# 3        na      3
# 4        oa      2
# 5        sa     17

# %%
#先畫五大洲的國家個數
#Ｘ軸為州名、Y軸為個數

sns.barplot(x='Continent',y='Count', data=count_by_continent)
# Out:
# <AxesSubplot:xlabel='Continent', ylabel='Count'>

# %%
#show the number tags

ax = sns.barplot(x='Continent',y='Count', data=count_by_continent)

for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2, p.get_height()), ha='center', va='bottom')

# %% [markdown]
# # 世界前五名的 Hapiness Score BAR圖

# %%
#篩選Happiness score前幾名並印出結果
import pandas as pd
def filter_top_values(csv_file, column_name, num_values, selected_columns):
    # 讀取 CSV 檔案
    df = pd.read_csv(csv_file)
    
    # 按數值欄位排序
    sorted_df = df.sort_values(by=column_name, ascending=False)
    
    # 篩選前幾大的資料
    filtered_df = sorted_df.head(num_values)
    
    # 只取特定行(column)的資料
    filtered_data = filtered_df[selected_columns]
    
    return filtered_data

# 設定檔案路徑、欄位名稱、要篩選的前幾大數值、要印出的特定行(column)
csv_file = '/Users/ziyon/Documents/Business Programming/Final Project/World Happiness Report 2022 - World Happiness Report 2022.csv'
column_name = 'Happiness score'
num_values = 5
selected_columns = ['RANK','Country', 'Happiness score']

# 執行篩選並印出特定行(column)的結果
filtered_data = filter_top_values(csv_file, column_name, num_values, selected_columns)
print(filtered_data)
# Out:
#    RANK      Country  Happiness score
# 0     1      Finland            7.821
# 1     2      Denmark            7.636
# 2     3      Iceland            7.557
# 3     4  Switzerland            7.512
# 4     5  Netherlands            7.415

# %%
filtered_data

top_5 = sns.barplot(x='Country',y='Happiness score', data=filtered_data)

#數值標籤
for p in top_5.patches:
    top_5.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2, p.get_height()), ha='center', va='bottom')

# %% [markdown]
# # 世界前五名的六項指標Bar圖

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

def filter_top_values(csv_file, column_name, num_values, selected_columns):
    # Read the CSV file
    df = pd.read_csv(csv_file)
    
    # Sort the DataFrame by the column_name in descending order
    sorted_df = df.sort_values(by=column_name, ascending=False)
    
    # Filter the top num_values
    filtered_df = sorted_df.head(num_values)
    
    # Select the specified columns
    filtered_data = filtered_df[selected_columns]
    
    return filtered_data

# Set the file path, column name, number of values to filter, and selected columns to display
csv_file = '/Users/ziyon/Documents/Business Programming/Final Project/World Happiness Report 2022 - World Happiness Report 2022.csv'
column_name = 'Happiness score'
num_values = 5
selected_columns = ['Country','Dystopia (1.83) + residual','GDP per capita', 'Social support', 'Healthy life expectancy',
                    'Freedom to make life choices', 'Generosity', 'Perceptions of corruption']

# Execute the filter and retrieve the filtered data
filtered_data = filter_top_values(csv_file, column_name, num_values, selected_columns)

filtered_data
# Out:
#        Country  Dystopia (1.83) + residual  GDP per capita  Social support  \
# 0      Finland                       2.518           1.892           1.258
# 1      Denmark                       2.226           1.953           1.243
# 2      Iceland                       2.320           1.936           1.320
# 3  Switzerland                       2.153           2.026           1.226
# 4  Netherlands                       2.137           1.945           1.206
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.775                         0.736       0.109
# 1                    0.777                         0.719       0.188
# 2                    0.803                         0.718       0.270
# 3                    0.822                         0.677       0.147
# 4                    0.787                         0.651       0.271
#
#    Perceptions of corruption
# 0                      0.534
# 1                      0.532
# 2                      0.191
# 3                      0.461
# 4                      0.419

# %%
# Melt the DataFrame to convert the factors into a single column
melted_data = pd.melt(filtered_data, id_vars='Country', value_vars=selected_columns[1:])


melted_data
# Out:
#         Country                      variable  value
# 0       Finland    Dystopia (1.83) + residual  2.518
# 1       Denmark    Dystopia (1.83) + residual  2.226
# 2       Iceland    Dystopia (1.83) + residual  2.320
# 3   Switzerland    Dystopia (1.83) + residual  2.153
# 4   Netherlands    Dystopia (1.83) + residual  2.137
# 5       Finland                GDP per capita  1.892
# 6       Denmark                GDP per capita  1.953
# 7       Iceland                GDP per capita  1.936
# 8   Switzerland                GDP per capita  2.026
# 9   Netherlands                GDP per capita  1.945
# 10      Finland                Social support  1.258
# 11      Denmark                Social support  1.243
# 12      Iceland                Social support  1.320
# 13  Switzerland                Social support  1.226
# 14  Netherlands                Social support  1.206
# 15      Finland       Healthy life expectancy  0.775
# 16      Denmark       Healthy life expectancy  0.777
# 17      Iceland       Healthy life expectancy  0.803
# 18  Switzerland       Healthy life expectancy  0.822
# 19  Netherlands       Healthy life expectancy  0.787
# 20      Finland  Freedom to make life choices  0.736
# 21      Denmark  Freedom to make life choices  0.719
# 22      Iceland  Freedom to make life choices  0.718
# 23  Switzerland  Freedom to make life choices  0.677
# 24  Netherlands  Freedom to make life choices  0.651
# 25      Finland                    Generosity  0.109
# 26      Denmark                    Generosity  0.188
# 27      Iceland                    Generosity  0.270
# 28  Switzerland                    Generosity  0.147
# 29  Netherlands                    Generosity  0.271
# 30      Finland     Perceptions of corruption  0.534
# 31      Denmark     Perceptions of corruption  0.532
# 32      Iceland     Perceptions of corruption  0.191
# 33  Switzerland     Perceptions of corruption  0.461
# 34  Netherlands     Perceptions of corruption  0.419

# %% [markdown]
# # 各州前五名Happiness Score

# %% [markdown]
# # 亞洲

# %%
df = pd.read_csv('/Users/ziyon/Documents/Business Programming/Final Project/asia.csv')

as5 = df.nlargest(5,'Happiness score')
as5
# Out:
#    RANK                   Country Continent  Happiness score  Whisker-high  \
# 0     9                    Israel        as            7.364         7.426
# 1    21                   Bahrain        as            6.647         6.779
# 2    24      United Arab Emirates        as            6.576         6.660
# 3    25              Saudi Arabia        as            6.523         6.637
# 4    26  Taiwan Province of China        as            6.512         6.596
#
#    Whisker-low  Dystopia (1.83) + residual  GDP per capita  Social support  \
# 0        7.301                       2.634           1.826           1.221
# 1        6.514                       2.092           1.854           1.029
# 2        6.492                       1.809           1.998           0.980
# 3        6.409                       2.075           1.870           1.092
# 4        6.429                       2.002           1.897           1.095
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.818                         0.568       0.155
# 1                    0.625                         0.693       0.199
# 2                    0.633                         0.702       0.204
# 3                    0.577                         0.651       0.078
# 4                    0.733                         0.542       0.075
#
#    Perceptions of corruption
# 0                      0.143
# 1                      0.155
# 2                      0.250
# 3                      0.180
# 4                      0.168

# %%
# Melt the DataFrame to convert the factors into a single column
melted_data = pd.melt(as5, id_vars='Country', value_vars=selected_columns[1:])
melted_data.head(5)
# Out:
#                     Country                    variable  value
# 0                    Israel  Dystopia (1.83) + residual  2.634
# 1                   Bahrain  Dystopia (1.83) + residual  2.092
# 2      United Arab Emirates  Dystopia (1.83) + residual  1.809
# 3              Saudi Arabia  Dystopia (1.83) + residual  2.075
# 4  Taiwan Province of China  Dystopia (1.83) + residual  2.002

# %%
# Calculate the sums for each country
sums_by_country = melted_data.groupby('Country')['value'].transform('sum')

# Assign the sums as the "Happiness Score" column
melted_data['Happiness Score'] = sums_by_country

# Display the updated DataFrame
melted_data.head()
# Out:
#                     Country                    variable  value  \
# 0                    Israel  Dystopia (1.83) + residual  2.634
# 1                   Bahrain  Dystopia (1.83) + residual  2.092
# 2      United Arab Emirates  Dystopia (1.83) + residual  1.809
# 3              Saudi Arabia  Dystopia (1.83) + residual  2.075
# 4  Taiwan Province of China  Dystopia (1.83) + residual  2.002
#
#    Happiness Score
# 0            7.365
# 1            6.647
# 2            6.576
# 3            6.523
# 4            6.512

# %%
stacked_plot = sns.histplot(data=melted_data, x='Country', hue='variable', weights='value', multiple='stack')
stacked_plot

# Set the labels and legend
stacked_plot.set_ylabel('Country')
stacked_plot.set_xlabel('Happiness Score')

#remove the legend
#stacked_plot.legend_.remove()

#move the legend out of the plot
sns.move_legend(stacked_plot, "upper left", bbox_to_anchor=(1, 1))


stacked_plot.tick_params(axis='x',labelsize=8,rotation=20)


# iterate through each container
for c in stacked_plot.containers:

    # Optional: if the segment is small or 0, customize the labels
    labels = [round(v.get_height(),2) if v.get_height() > 0.1 else '' for v in c]
    
    # remove the labels parameter if it's not needed for customized labels
    stacked_plot.bar_label(c, labels=labels, label_type='center')

# %%
stacked_plot = sns.histplot(data=melted_data, y='Country', hue='variable', weights='value', multiple='stack')
stacked_plot

#sns.histplot(data=penguins, y="flipper_length_mm")

# Set the labels and legend
stacked_plot.set_ylabel('Country')
stacked_plot.set_xlabel('Happiness Score')

#remove the legend
#stacked_plot.legend_.remove()

#move the legend out of the plot
sns.move_legend(stacked_plot, "upper left", bbox_to_anchor=(1, 1))


stacked_plot.tick_params(axis='y',labelsize=8,rotation=20)


# iterate through each container
for c in stacked_plot.containers:

    # Optional: if the segment is small or 0, customize the labels
    labels = [round(v.get_width(),2) if v.get_width() > 0.3 else '' for v in c]
    
    # remove the labels parameter if it's not needed for customized labels
    stacked_plot.bar_label(c, labels=labels, label_type='center')

# %% [markdown]
# # 歐洲

# %%
df = pd.read_csv('/Users/ziyon/Documents/Business Programming/Final Project/euro.csv')

eu5 = df.nlargest(5,'Happiness score')

# Melt the DataFrame to convert the factors into a single column
melted_data = pd.melt(eu5, id_vars='Country', value_vars=selected_columns[1:])
melted_data.head()
# Out:
#        Country                    variable  value
# 0      Finland  Dystopia (1.83) + residual  2.518
# 1      Denmark  Dystopia (1.83) + residual  2.226
# 2      Iceland  Dystopia (1.83) + residual  2.320
# 3  Switzerland  Dystopia (1.83) + residual  2.153
# 4  Netherlands  Dystopia (1.83) + residual  2.137

# %%
# Calculate the sums for each country
sums_by_country = melted_data.groupby('Country')['value'].transform('sum')

# Assign the sums as the "Happiness Score" column
melted_data['Happiness Score'] = sums_by_country

# Display the updated DataFrame
melted_data.head()
# Out:
#        Country                    variable  value  Happiness Score
# 0      Finland  Dystopia (1.83) + residual  2.518            7.822
# 1      Denmark  Dystopia (1.83) + residual  2.226            7.638
# 2      Iceland  Dystopia (1.83) + residual  2.320            7.558
# 3  Switzerland  Dystopia (1.83) + residual  2.153            7.512
# 4  Netherlands  Dystopia (1.83) + residual  2.137            7.416

# %%
stacked_plot = sns.histplot(data=melted_data, y='Country', hue='variable', weights='value', multiple='stack')
stacked_plot

# Set the labels and legend
stacked_plot.set_ylabel('Country')
stacked_plot.set_xlabel('Happiness Score')

#remove the legend
#stacked_plot.legend_.remove()

#move the legend out of the plot
sns.move_legend(stacked_plot, "upper left", bbox_to_anchor=(1, 1))


stacked_plot.tick_params(axis='y',labelsize=8,rotation=20)


# iterate through each container
for c in stacked_plot.containers:

    # Optional: if the segment is small or 0, customize the labels
    labels = [round(v.get_width(),2) if v.get_width() > 0.2 else '' for v in c]
    
    # remove the labels parameter if it's not needed for customized labels
    stacked_plot.bar_label(c, labels=labels, label_type='center')

# %% [markdown]
# # 非洲

# %%
df = pd.read_csv('/Users/ziyon/Documents/Business Programming/Final Project/africa.csv')

af5 = df.nlargest(5,'Happiness score')

# Melt the DataFrame to convert the factors into a single column
melted_data = pd.melt(af5, id_vars='Country', value_vars=selected_columns[1:])
melted_data.head()
# Out:
#        Country                    variable  value
# 0        Malta  Dystopia (1.83) + residual  1.631
# 1    Mauritius  Dystopia (1.83) + residual  1.969
# 2      Jamaica  Dystopia (1.83) + residual  2.164
# 3       Libya*  Dystopia (1.83) + residual  1.544
# 4  Ivory Coast  Dystopia (1.83) + residual  2.652

# %%
# Calculate the sums for each country
sums_by_country = melted_data.groupby('Country')['value'].transform('sum')

# Assign the sums as the "Happiness Score" column
melted_data['Happiness Score'] = sums_by_country

# Display the updated DataFrame
melted_data.head()
# Out:
#        Country                    variable  value  Happiness Score
# 0        Malta  Dystopia (1.83) + residual  1.631            6.446
# 1    Mauritius  Dystopia (1.83) + residual  1.969            6.071
# 2      Jamaica  Dystopia (1.83) + residual  2.164            5.851
# 3       Libya*  Dystopia (1.83) + residual  1.544            5.331
# 4  Ivory Coast  Dystopia (1.83) + residual  2.652            5.234

# %%
stacked_plot = sns.histplot(data=melted_data, y='Country', hue='variable', weights='value', multiple='stack')
stacked_plot

# Set the labels and legend
stacked_plot.set_ylabel('Country')
stacked_plot.set_xlabel('Happiness Score')

#remove the legend
#stacked_plot.legend_.remove()

#move the legend out of the plot
sns.move_legend(stacked_plot, "upper left", bbox_to_anchor=(1, 1))


stacked_plot.tick_params(axis='y',labelsize=8,rotation=20)


# iterate through each container
for c in stacked_plot.containers:

    # Optional: if the segment is small or 0, customize the labels
    labels = [round(v.get_width(),2) if v.get_width() > 0.2 else '' for v in c]
    
    # remove the labels parameter if it's not needed for customized labels
    stacked_plot.bar_label(c, labels=labels, label_type='center')

# %% [markdown]
# # 北美洲

# %%
df = pd.read_csv('/Users/ziyon/Documents/Business Programming/Final Project/na.csv')

af5 = df.nlargest(5,'Happiness score')

# Melt the DataFrame to convert the factors into a single column
melted_data = pd.melt(af5, id_vars='Country', value_vars=selected_columns[1:])
melted_data.head()
# Out:
#          Country                    variable  value
# 0         Canada  Dystopia (1.83) + residual  1.924
# 1  United States  Dystopia (1.83) + residual  2.214
# 2     Costa Rica  Dystopia (1.83) + residual  2.346
# 3         Canada              GDP per capita  1.886
# 4  United States              GDP per capita  1.982

# %%
# Calculate the sums for each country
sums_by_country = melted_data.groupby('Country')['value'].transform('sum')

# Assign the sums as the "Happiness Score" column
melted_data['Happiness Score'] = sums_by_country

# Display the updated DataFrame
melted_data.head()
# Out:
#          Country                    variable  value  Happiness Score
# 0         Canada  Dystopia (1.83) + residual  1.924            7.025
# 1  United States  Dystopia (1.83) + residual  2.214            6.977
# 2     Costa Rica  Dystopia (1.83) + residual  2.346            6.580
# 3         Canada              GDP per capita  1.886            7.025
# 4  United States              GDP per capita  1.982            6.977

# %%
stacked_plot = sns.histplot(data=melted_data, y='Country', hue='variable', weights='value', multiple='stack')
stacked_plot

# Set the labels and legend
stacked_plot.set_ylabel('Country')
stacked_plot.set_xlabel('Happiness Score')

#remove the legend
#stacked_plot.legend_.remove()

#move the legend out of the plot
sns.move_legend(stacked_plot, "upper left", bbox_to_anchor=(1, 1))


stacked_plot.tick_params(axis='y',labelsize=8,rotation=20)


# iterate through each container
for c in stacked_plot.containers:

    # Optional: if the segment is small or 0, customize the labels
    labels = [round(v.get_width(),2) if v.get_width() > 0.3 else '' for v in c]
    
    # remove the labels parameter if it's not needed for customized labels
    stacked_plot.bar_label(c, labels=labels, label_type='center')

# %% [markdown]
# # 澳洲

# %%
df = pd.read_csv('/Users/ziyon/Documents/Business Programming/Final Project/oa.csv')

oa5 = df.nlargest(2,'Happiness score')

# Melt the DataFrame to convert the factors into a single column
melted_data = pd.melt(oa5, id_vars='Country', value_vars=selected_columns[1:])
melted_data.head()

# Calculate the sums for each country
sums_by_country = melted_data.groupby('Country')['value'].transform('sum')

# Assign the sums as the "Happiness Score" column
melted_data['Happiness Score'] = sums_by_country

# Display the updated DataFrame
melted_data.head()
# Out:
#        Country                    variable  value  Happiness Score
# 0  New Zealand  Dystopia (1.83) + residual  1.954            7.201
# 1    Australia  Dystopia (1.83) + residual  2.011            7.161
# 2  New Zealand              GDP per capita  1.852            7.201
# 3    Australia              GDP per capita  1.900            7.161
# 4  New Zealand              Social support  1.235            7.201

# %%
stacked_plot = sns.histplot(data=melted_data, y='Country', hue='variable', weights='value', multiple='stack')
stacked_plot

# Set the labels and legend
stacked_plot.set_ylabel('Country')
stacked_plot.set_xlabel('Happiness Score')

#remove the legend
#stacked_plot.legend_.remove()

#move the legend out of the plot
sns.move_legend(stacked_plot, "upper left", bbox_to_anchor=(1, 1))


stacked_plot.tick_params(axis='y',labelsize=8,rotation=20)


# iterate through each container
for c in stacked_plot.containers:

    # Optional: if the segment is small or 0, customize the labels
    labels = [round(v.get_width(),2) if v.get_width() > 0.3 else '' for v in c]
    
    # remove the labels parameter if it's not needed for customized labels
    stacked_plot.bar_label(c, labels=labels, label_type='center')

# %% [markdown]
# # 南美洲

# %%
df = pd.read_csv('/Users/ziyon/Documents/Business Programming/Final Project/sa.csv')

af5 = df.nlargest(5,'Happiness score')

# Melt the DataFrame to convert the factors into a single column
melted_data = pd.melt(af5, id_vars='Country', value_vars=selected_columns[1:])
melted_data.head()

# Calculate the sums for each country
sums_by_country = melted_data.groupby('Country')['value'].transform('sum')

# Assign the sums as the "Happiness Score" column
melted_data['Happiness Score'] = sums_by_country

# Display the updated DataFrame
melted_data.head()
# Out:
#       Country                    variable  value  Happiness Score
# 0     Uruguay  Dystopia (1.83) + residual  1.974            6.474
# 1      Panama  Dystopia (1.83) + residual  2.086            6.309
# 2      Brazil  Dystopia (1.83) + residual  2.361            6.293
# 3  Guatemala*  Dystopia (1.83) + residual  2.746            6.262
# 4       Chile  Dystopia (1.83) + residual  2.040            6.172

# %%
stacked_plot = sns.histplot(data=melted_data, y='Country', hue='variable', weights='value', multiple='stack')
stacked_plot

# Set the labels and legend
stacked_plot.set_ylabel('Country')
stacked_plot.set_xlabel('Happiness Score')

#remove the legend
#stacked_plot.legend_.remove()

#move the legend out of the plot
sns.move_legend(stacked_plot, "upper left", bbox_to_anchor=(1, 1))


stacked_plot.tick_params(axis='y',labelsize=8,rotation=20)


# iterate through each container
for c in stacked_plot.containers:

    # Optional: if the segment is small or 0, customize the labels
    labels = [round(v.get_width(),2) if v.get_width() > 0.3 else '' for v in c]
    
    # remove the labels parameter if it's not needed for customized labels
    stacked_plot.bar_label(c, labels=labels, label_type='center')
