# %%
import pandas as pd

df = pd.read_csv('/Users/ziyon/Documents/Business Programming/Final Project/World Happiness Report 2022 - World Happiness Report 2022.csv')

df
# Out:
#      RANK      Country Continent  Happiness score  Whisker-high  Whisker-low  \
# 0       1      Finland        eu            7.821         7.886        7.756
# 1       2      Denmark        eu            7.636         7.710        7.563
# 2       3      Iceland        eu            7.557         7.651        7.464
# 3       4  Switzerland        eu            7.512         7.586        7.437
# 4       5  Netherlands        eu            7.415         7.471        7.359
# ..    ...          ...       ...              ...           ...          ...
# 141   142    Botswana*        af            3.471         3.667        3.275
# 142   143      Rwanda*        af            3.268         3.462        3.074
# 143   144     Zimbabwe        af            2.995         3.110        2.880
# 144   145      Lebanon        as            2.955         3.049        2.862
# 145   146  Afghanistan        as            2.404         2.469        2.339
#
# ...

# %%
africa = df[df['Continent'] == 'af']
africa
# Out:
#      RANK                Country Continent  Happiness score  Whisker-high  \
# 32     33                  Malta        af            6.447         6.535
# 51     52              Mauritius        af            6.071         6.184
# 62     63                Jamaica        af            5.850         6.023
# 85     86                 Libya*        af            5.330         5.543
# 87     88            Ivory Coast        af            5.235         5.384
# 90     91           South Africa        af            5.194         5.315
# 92     93                Gambia*        af            5.164         5.409
# 95     96                Algeria        af            5.122         5.215
# 96     97               Liberia*        af            5.122         5.428
# 98     99                  Congo        af            5.075         5.235
# 99    100                Morocco        af            5.060         5.181
# 100   101             Mozambique        af            5.048         5.273
# ...

# %%
africa.to_csv('/Users/ziyon/Documents/Business Programming/Final Project/africa.csv', index=False)

# %% [markdown]
# # 非洲前五名

# %%
#篩選Happiness score前幾名並印出結果
import pandas as pd
def filter_top_values(csv_file, column_name, num_values, selected_columns):
    # 讀取 CSV 檔案
    df = pd.read_csv(csv_file)
    
    # 按數值欄位排序
    sorted_df = df.sort_values(by=column_name, ascending=False)
    
    # 篩選前幾大的資料
    filtered_df = sorted_df.head(num_values)
    
    # 只取特定行(column)的資料
    filtered_data = filtered_df[selected_columns]
    
    return filtered_data

# 設定檔案路徑、欄位名稱、要篩選的前幾大數值、要印出的特定行(column)
csv_file = '/Users/ziyon/Documents/Business Programming/Final Project/africa.csv'
column_name = 'Happiness score'
num_values = 5
selected_columns = ['RANK','Country','Continent','Happiness score','Dystopia (1.83) + residual','GDP per capita','Social support','Healthy life expectancy','Freedom to make life choices','Generosity','Perceptions of corruption']

# 執行篩選並印出特定行(column)的結果
africa5 = filter_top_values(csv_file, column_name, num_values, selected_columns)
print(africa5)
# Out:
#    RANK      Country Continent  Happiness score  Dystopia (1.83) + residual  \
# 0    33        Malta        af            6.447                       1.631
# 1    52    Mauritius        af            6.071                       1.969
# 2    63      Jamaica        af            5.850                       2.164
# 3    86       Libya*        af            5.330                       1.544
# 4    88  Ivory Coast        af            5.235                       2.652
#
#    GDP per capita  Social support  Healthy life expectancy  \
# 0           1.838           1.169                    0.789
# 1           1.591           1.116                    0.568
# 2           1.296           1.045                    0.646
# 3           1.476           0.943                    0.606
# 4           1.094           0.442                    0.322
#
#    Freedom to make life choices  Generosity  Perceptions of corruption
# 0                         0.679       0.174                      0.166
# ...

# %%
new = sns.barplot(data=africa5, x="Happiness score", y="Country")

for i in new.containers:
    new.bar_label(i,)

new
# Out:
# <AxesSubplot:xlabel='Happiness score', ylabel='Country'>

# %% [markdown]
# # 亞洲前五

# %%
#篩選Happiness score前幾名並印出結果
import pandas as pd
def filter_top_values(csv_file, column_name, num_values, selected_columns):
    # 讀取 CSV 檔案
    df = pd.read_csv(csv_file)
    
    # 按數值欄位排序
    sorted_df = df.sort_values(by=column_name, ascending=False)
    
    # 篩選前幾大的資料
    filtered_df = sorted_df.head(num_values)
    
    # 只取特定行(column)的資料
    filtered_data = filtered_df[selected_columns]
    
    return filtered_data

# 設定檔案路徑、欄位名稱、要篩選的前幾大數值、要印出的特定行(column)
csv_file = '/Users/ziyon/Documents/Business Programming/Final Project/asia.csv'
column_name = 'Happiness score'
num_values = 5
selected_columns = ['RANK','Country','Continent','Happiness score','Dystopia (1.83) + residual','GDP per capita','Social support','Healthy life expectancy','Freedom to make life choices','Generosity','Perceptions of corruption']

# 執行篩選並印出特定行(column)的結果
asia5 = filter_top_values(csv_file, column_name, num_values, selected_columns)
print(asia5)
# Out:
#    RANK                   Country Continent  Happiness score  \
# 0     9                    Israel        as            7.364
# 1    21                   Bahrain        as            6.647
# 2    24      United Arab Emirates        as            6.576
# 3    25              Saudi Arabia        as            6.523
# 4    26  Taiwan Province of China        as            6.512
#
#    Dystopia (1.83) + residual  GDP per capita  Social support  \
# 0                       2.634           1.826           1.221
# 1                       2.092           1.854           1.029
# 2                       1.809           1.998           0.980
# 3                       2.075           1.870           1.092
# 4                       2.002           1.897           1.095
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.818                         0.568       0.155
# 1                    0.625                         0.693       0.199
# ...

# %%
new = sns.barplot(data=asia5, x="Happiness score", y="Country")

for i in new.containers:
    new.bar_label(i,)

new
# Out:
# <AxesSubplot:xlabel='Happiness score', ylabel='Country'>

# %% [markdown]
# # 歐洲前五名

# %%
euro = df[df['Continent'] == 'eu']
euro.to_csv('/Users/ziyon/Documents/Business Programming/Final Project/euro.csv', index=False)


#篩選Happiness score前幾名並印出結果
import pandas as pd
def filter_top_values(csv_file, column_name, num_values, selected_columns):
    # 讀取 CSV 檔案
    df = pd.read_csv(csv_file)
    
    # 按數值欄位排序
    sorted_df = df.sort_values(by=column_name, ascending=False)
    
    # 篩選前幾大的資料
    filtered_df = sorted_df.head(num_values)
    
    # 只取特定行(column)的資料
    filtered_data = filtered_df[selected_columns]
    
    return filtered_data

# 設定檔案路徑、欄位名稱、要篩選的前幾大數值、要印出的特定行(column)
csv_file = '/Users/ziyon/Documents/Business Programming/Final Project/euro.csv'
column_name = 'Happiness score'
num_values = 5
selected_columns = ['RANK','Country','Continent','Happiness score','Dystopia (1.83) + residual','GDP per capita','Social support','Healthy life expectancy','Freedom to make life choices','Generosity','Perceptions of corruption']

# 執行篩選並印出特定行(column)的結果
euro5 = filter_top_values(csv_file, column_name, num_values, selected_columns)
print(euro5)
# Out:
#    RANK      Country Continent  Happiness score  Dystopia (1.83) + residual  \
# 0     1      Finland        eu            7.821                       2.518
# 1     2      Denmark        eu            7.636                       2.226
# 2     3      Iceland        eu            7.557                       2.320
# 3     4  Switzerland        eu            7.512                       2.153
# 4     5  Netherlands        eu            7.415                       2.137
#
#    GDP per capita  Social support  Healthy life expectancy  \
# 0           1.892           1.258                    0.775
# 1           1.953           1.243                    0.777
# 2           1.936           1.320                    0.803
# 3           2.026           1.226                    0.822
# 4           1.945           1.206                    0.787
#
#    Freedom to make life choices  Generosity  Perceptions of corruption
# 0                         0.736       0.109                      0.534
# ...

# %%
new = sns.barplot(data=euro5, x="Happiness score", y="Country")

for i in new.containers:
    new.bar_label(i,)

new
# Out:
# <AxesSubplot:xlabel='Happiness score', ylabel='Country'>

# %% [markdown]
# # 北美前五名

# %%
euro = df[df['Continent'] == 'na']
euro.to_csv('/Users/ziyon/Documents/Business Programming/Final Project/na.csv', index=False)


#篩選Happiness score前幾名並印出結果
import pandas as pd
def filter_top_values(csv_file, column_name, num_values, selected_columns):
    # 讀取 CSV 檔案
    df = pd.read_csv(csv_file)
    
    # 按數值欄位排序
    sorted_df = df.sort_values(by=column_name, ascending=False)
    
    # 篩選前幾大的資料
    filtered_df = sorted_df.head(num_values)
    
    # 只取特定行(column)的資料
    filtered_data = filtered_df[selected_columns]
    
    return filtered_data

# 設定檔案路徑、欄位名稱、要篩選的前幾大數值、要印出的特定行(column)
csv_file = '/Users/ziyon/Documents/Business Programming/Final Project/na.csv'
column_name = 'Happiness score'
num_values = 5
selected_columns = ['RANK','Country','Continent','Happiness score','Dystopia (1.83) + residual','GDP per capita','Social support','Healthy life expectancy','Freedom to make life choices','Generosity','Perceptions of corruption']

# 執行篩選並印出特定行(column)的結果
na5 = filter_top_values(csv_file, column_name, num_values, selected_columns)
print(na5)
# Out:
#    RANK        Country Continent  Happiness score  Dystopia (1.83) + residual  \
# 0    15         Canada        na            7.025                       1.924
# 1    16  United States        na            6.977                       2.214
# 2    23     Costa Rica        na            6.582                       2.346
#
#    GDP per capita  Social support  Healthy life expectancy  \
# 0           1.886           1.188                    0.783
# 1           1.982           1.182                    0.628
# 2           1.584           1.054                    0.744
#
#    Freedom to make life choices  Generosity  Perceptions of corruption
# 0                         0.659       0.217                      0.368
# 1                         0.574       0.220                      0.177
# 2                         0.661       0.089                      0.102

# %%
new = sns.barplot(data=na5, x="Happiness score", y="Country")

for i in new.containers:
    new.bar_label(i,)

new
# Out:
# <AxesSubplot:xlabel='Happiness score', ylabel='Country'>

# %% [markdown]
# # 南美前五名

# %%
sa = df[df['Continent'] == 'sa']
sa.to_csv('/Users/ziyon/Documents/Business Programming/Final Project/sa.csv', index=False)


#篩選Happiness score前幾名並印出結果
import pandas as pd
def filter_top_values(csv_file, column_name, num_values, selected_columns):
    # 讀取 CSV 檔案
    df = pd.read_csv(csv_file)
    
    # 按數值欄位排序
    sorted_df = df.sort_values(by=column_name, ascending=False)
    
    # 篩選前幾大的資料
    filtered_df = sorted_df.head(num_values)
    
    # 只取特定行(column)的資料
    filtered_data = filtered_df[selected_columns]
    
    return filtered_data

# 設定檔案路徑、欄位名稱、要篩選的前幾大數值、要印出的特定行(column)
csv_file = '/Users/ziyon/Documents/Business Programming/Final Project/sa.csv'
column_name = 'Happiness score'
num_values = 5
selected_columns = ['RANK','Country','Continent','Happiness score','Dystopia (1.83) + residual','GDP per capita','Social support','Healthy life expectancy','Freedom to make life choices','Generosity','Perceptions of corruption']

# 執行篩選並印出特定行(column)的結果
sa5 = filter_top_values(csv_file, column_name, num_values, selected_columns)
print(sa5)
# Out:
#    RANK     Country Continent  Happiness score  Dystopia (1.83) + residual  \
# 0    30     Uruguay        sa            6.474                       1.974
# 1    37      Panama        sa            6.309                       2.086
# 2    38      Brazil        sa            6.293                       2.361
# 3    39  Guatemala*        sa            6.262                       2.746
# 4    44       Chile        sa            6.172                       2.040
#
#    GDP per capita  Social support  Healthy life expectancy  \
# 0           1.615           1.180                    0.672
# 1           1.715           1.107                    0.709
# 2           1.462           1.044                    0.615
# 3           1.274           0.831                    0.522
# 4           1.651           1.080                    0.748
#
#    Freedom to make life choices  Generosity  Perceptions of corruption
# 0                         0.665       0.103                      0.265
# ...

# %%
new = sns.barplot(data=sa5, x="Happiness score", y="Country")

for i in new.containers:
    new.bar_label(i,)

new
# Out:
# <AxesSubplot:xlabel='Happiness score', ylabel='Country'>

# %% [markdown]
# # 澳洲前五名

# %%
oa = df[df['Continent'] == 'oa']
oa.to_csv('/Users/ziyon/Documents/Business Programming/Final Project/oa.csv', index=False)


#篩選Happiness score前幾名並印出結果
import pandas as pd
def filter_top_values(csv_file, column_name, num_values, selected_columns):
    # 讀取 CSV 檔案
    df = pd.read_csv(csv_file)
    
    # 按數值欄位排序
    sorted_df = df.sort_values(by=column_name, ascending=False)
    
    # 篩選前幾大的資料
    filtered_df = sorted_df.head(num_values)
    
    # 只取特定行(column)的資料
    filtered_data = filtered_df[selected_columns]
    
    return filtered_data

# 設定檔案路徑、欄位名稱、要篩選的前幾大數值、要印出的特定行(column)
csv_file = '/Users/ziyon/Documents/Business Programming/Final Project/oa.csv'
column_name = 'Happiness score'
num_values = 5
selected_columns = ['RANK','Country','Continent','Happiness score','Dystopia (1.83) + residual','GDP per capita','Social support','Healthy life expectancy','Freedom to make life choices','Generosity','Perceptions of corruption']

# 執行篩選並印出特定行(column)的結果
oa5 = filter_top_values(csv_file, column_name, num_values, selected_columns)
print(oa5)
# Out:
#    RANK      Country Continent  Happiness score  Dystopia (1.83) + residual  \
# 0    10  New Zealand        oa            7.200                       1.954
# 1    12    Australia        oa            7.162                       2.011
#
#    GDP per capita  Social support  Healthy life expectancy  \
# 0           1.852           1.235                    0.752
# 1           1.900           1.203                    0.772
#
#    Freedom to make life choices  Generosity  Perceptions of corruption
# 0                         0.680       0.245                      0.483
# 1                         0.676       0.258                      0.341

# %%
new = sns.barplot(data=oa5, x="Happiness score", y="Country")

for i in new.containers:
    new.bar_label(i,)

new
# Out:
# <AxesSubplot:xlabel='Happiness score', ylabel='Country'>

# %% [markdown]
# # 垂直併表

# %%
# Concatenate the two DataFrames vertically
Continet_Top5 = pd.concat([asia5, africa5,euro5,na5,sa5,oa])

# Reset the index of the concatenated DataFrame
Continet_Top5 = Continet_Top5.reset_index(drop=True)

# %%
Continet_Top5
# Out:
#     RANK                   Country Continent  Happiness score  \
# 0      9                    Israel        as            7.364
# 1     21                   Bahrain        as            6.647
# 2     24      United Arab Emirates        as            6.576
# 3     25              Saudi Arabia        as            6.523
# 4     26  Taiwan Province of China        as            6.512
# 5     33                     Malta        af            6.447
# 6     52                 Mauritius        af            6.071
# 7     63                   Jamaica        af            5.850
# 8     86                    Libya*        af            5.330
# 9     88               Ivory Coast        af            5.235
# 10     1                   Finland        eu            7.821
# 11     2                   Denmark        eu            7.636
# 12     3                   Iceland        eu            7.557
# 13     4               Switzerland        eu            7.512
# ...

# %% [markdown]
# # Top 5 Scatter

# %%
Continet_Top5
# %config InlineBackend.figure_format = 'retina'

R = sns.scatterplot(x='Happiness score', y ='Dystopia (1.83) + residual', data=Continet_Top5, hue = 'Continent')

# %%
gdp = sns.scatterplot(x='Happiness score', y ='GDP per capita', data=Continet_Top5, hue = 'Continent')

# %%
ss = sns.scatterplot(x='Happiness score', y ='Social support', data=Continet_Top5, hue = 'Continent')

# %%
hle = sns.scatterplot(x='Happiness score', y ='Healthy life expectancy', data=Continet_Top5, hue = 'Continent')

# %%
F = sns.scatterplot(x='Happiness score', y ='Freedom to make life choices', data=Continet_Top5, hue = 'Continent')

# %%
G = sns.scatterplot(x='Happiness score', y ='Generosity', data=Continet_Top5, hue = 'Continent')

# %%
P = sns.scatterplot(x='Happiness score', y ='Perceptions of corruption', data=Continet_Top5, hue = 'Continent')
