# %%
import pandas as pd

df = pd.read_csv('/Users/ziyon/Documents/Business Programming/Final Project/World Happiness Report 2022 - World Happiness Report 2022.csv')

df
# Out:
#      RANK      Country Continent  Happiness score  Whisker-high  Whisker-low  \
# 0       1      Finland        eu            7.821         7.886        7.756
# 1       2      Denmark        eu            7.636         7.710        7.563
# 2       3      Iceland        eu            7.557         7.651        7.464
# 3       4  Switzerland        eu            7.512         7.586        7.437
# 4       5  Netherlands        eu            7.415         7.471        7.359
# ..    ...          ...       ...              ...           ...          ...
# 141   142    Botswana*        af            3.471         3.667        3.275
# 142   143      Rwanda*        af            3.268         3.462        3.074
# 143   144     Zimbabwe        af            2.995         3.110        2.880
# 144   145      Lebanon        as            2.955         3.049        2.862
# 145   146  Afghanistan        as            2.404         2.469        2.339
#
# ...

# %%
#set up
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# # 六洲快樂指數散佈程度

# %%
new = sns.stripplot(data=df, x="Happiness score", y="Continent")
new
# Out:
# <AxesSubplot:xlabel='Happiness score', ylabel='Continent'>

# %%
R = sns.scatterplot(x='Happiness score', y ='Dystopia (1.83) + residual', data=df, hue = 'Continent')

R
# Out:
# <AxesSubplot:xlabel='Happiness score', ylabel='Dystopia (1.83) + residual'>

# %%
import seaborn as sns

# Assuming you have a DataFrame 'df' with columns 'Happiness score', 'Dystopia (1.83) + residual', and 'Continent'

# Define a dictionary mapping continents to colors
continent_colors = {'as': 'red', 'eu': 'blue', 'af': 'green', 'na': 'orange', 'oa': 'purple','sa':'brown'}

# Create the scatter plot with assigned colors
R = sns.scatterplot(x='Happiness score', y='Dystopia (1.83) + residual', data=df, hue='Continent', palette=continent_colors)

# Add a legend with the continent labels
R.legend(title='Continent')

# Show the plot
plt.show()

# %%
gdp = sns.scatterplot(x='Happiness score', y ='GDP per capita', data=df, hue = 'Continent')

gdp
# Out:
# <AxesSubplot:xlabel='Happiness score', ylabel='GDP per capita'>

# %%
ss = sns.scatterplot(x='Happiness score', y ='Social support', data=df, hue = 'Continent')

ss
# Out:
# <AxesSubplot:xlabel='Happiness score', ylabel='Social support'>

# %%
hle = sns.scatterplot(x='Happiness score', y ='Healthy life expectancy', data=df, hue = 'Continent')
hle
# Out:
# <AxesSubplot:xlabel='Happiness score', ylabel='Healthy life expectancy'>

# %%
F = sns.scatterplot(x='Happiness score', y ='Freedom to make life choices', data=df, hue = 'Continent')

F
# Out:
# <AxesSubplot:xlabel='Happiness score', ylabel='Freedom to make life choices'>

# %%
G = sns.scatterplot(x='Happiness score', y ='Generosity', data=df, hue = 'Continent')

G
# Out:
# <AxesSubplot:xlabel='Happiness score', ylabel='Generosity'>

# %%
gdp = sns.scatterplot(x='Happiness score', y ='Perceptions of corruption', data=df, hue = 'Continent')

gdp
# Out:
# <AxesSubplot:xlabel='Happiness score', ylabel='Perceptions of corruption'>

# %% [markdown]
# # 各州前五名

# %%
asia = (df['Continent'] == 'as')#讀取亞洲
print(df.loc[asia])
# Out:
#      RANK                    Country Continent  Happiness score  Whisker-high  \
# 8       9                     Israel        as            7.364         7.426
# 20     21                    Bahrain        as            6.647         6.779
# 23     24       United Arab Emirates        as            6.576         6.660
# 24     25               Saudi Arabia        as            6.523         6.637
# 25     26   Taiwan Province of China        as            6.512         6.596
# 26     27                  Singapore        as            6.480         6.569
# 39     40                 Kazakhstan        as            6.234         6.330
# 40     41                     Cyprus        as            6.221         6.320
# 49     50                    Kuwait*        as            6.106         6.235
# 52     53                 Uzbekistan        as            6.063         6.178
# 53     54                      Japan        as            6.039         6.119
# ...

# %% [markdown]
# # 亞洲獨立資料

# %%
asia = df[df['Continent'] == 'as']
asia
# Out:
#      RANK                    Country Continent  Happiness score  Whisker-high  \
# 8       9                     Israel        as            7.364         7.426
# 20     21                    Bahrain        as            6.647         6.779
# 23     24       United Arab Emirates        as            6.576         6.660
# 24     25               Saudi Arabia        as            6.523         6.637
# 25     26   Taiwan Province of China        as            6.512         6.596
# 26     27                  Singapore        as            6.480         6.569
# 39     40                 Kazakhstan        as            6.234         6.330
# 40     41                     Cyprus        as            6.221         6.320
# 49     50                    Kuwait*        as            6.106         6.235
# 52     53                 Uzbekistan        as            6.063         6.178
# 53     54                      Japan        as            6.039         6.119
# ...

# %%
asia.to_csv('/Users/ziyon/Documents/Business Programming/Final Project/asia.csv', index=False)

# %%
aa = pd.read_csv('/Users/ziyon/Documents/Business Programming/Final Project/asia.csv')

aa
# Out:
#     RANK                    Country Continent  Happiness score  Whisker-high  \
# 0      9                     Israel        as            7.364         7.426
# 1     21                    Bahrain        as            6.647         6.779
# 2     24       United Arab Emirates        as            6.576         6.660
# 3     25               Saudi Arabia        as            6.523         6.637
# 4     26   Taiwan Province of China        as            6.512         6.596
# 5     27                  Singapore        as            6.480         6.569
# 6     40                 Kazakhstan        as            6.234         6.330
# 7     41                     Cyprus        as            6.221         6.320
# 8     50                    Kuwait*        as            6.106         6.235
# 9     53                 Uzbekistan        as            6.063         6.178
# 10    54                      Japan        as            6.039         6.119
# ...

# %% [markdown]
# # 亞洲前五名

# %%
#篩選Happiness score前幾名並印出結果
import pandas as pd
def filter_top_values(csv_file, column_name, num_values, selected_columns):
    # 讀取 CSV 檔案
    df = pd.read_csv(csv_file)
    
    # 按數值欄位排序
    sorted_df = df.sort_values(by=column_name, ascending=False)
    
    # 篩選前幾大的資料
    filtered_df = sorted_df.head(num_values)
    
    # 只取特定行(column)的資料
    filtered_data = filtered_df[selected_columns]
    
    return filtered_data

# 設定檔案路徑、欄位名稱、要篩選的前幾大數值、要印出的特定行(column)
csv_file = '/Users/ziyon/Documents/Business Programming/Final Project/asia.csv'
column_name = 'Happiness score'
num_values = 5
selected_columns = ['RANK','Country','Continent','Happiness score','Dystopia (1.83) + residual','GDP per capita','Social support','Healthy life expectancy','Freedom to make life choices','Generosity','Perceptions of corruption']

# 執行篩選並印出特定行(column)的結果
asia5 = filter_top_values(csv_file, column_name, num_values, selected_columns)
print(asia5)
# Out:
#    RANK                   Country Continent  Happiness score  \
# 0     9                    Israel        as            7.364
# 1    21                   Bahrain        as            6.647
# 2    24      United Arab Emirates        as            6.576
# 3    25              Saudi Arabia        as            6.523
# 4    26  Taiwan Province of China        as            6.512
#
#    Dystopia (1.83) + residual  GDP per capita  Social support  \
# 0                       2.634           1.826           1.221
# 1                       2.092           1.854           1.029
# 2                       1.809           1.998           0.980
# 3                       2.075           1.870           1.092
# 4                       2.002           1.897           1.095
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.818                         0.568       0.155
# 1                    0.625                         0.693       0.199
# ...

# %% [markdown]
# # 非洲前五名
